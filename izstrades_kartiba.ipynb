# %%
# Projekta izstrādes kārtība

## 1. posms – Projekta plānošana

Mērķis: definēt programmas ideju, funkcionalitāti un struktūru pirms kodēšanas.

Uzdevumi:

    * definēt programmas mērķi
    * aprakstīt datu struktūru
    * izplānot projekta moduļus
    * aprakstīt lietotāja scenārijus
    * identificēt robežgadījumus

Rezultāts:

    * izveidots dokuments **docs/plan.md**

---

## 2. posms – Datu saglabāšana

Mērķis: izveidot sistēmu izdevumu saglabāšanai un ielādei.

Uzdevumi:

    * izveidot JSON failu datu glabāšanai
    * implementēt funkciju `load_expenses()`
    * implementēt funkciju `save_expenses()`
    * pārbaudīt, vai programma darbojas, ja fails neeksistē

Rezultāts:

    * darbojas **storage.py**

---

## 3. posms – Programmas loģika

Mērķis: izveidot funkcijas datu apstrādei.

Uzdevumi:

    * filtrēt izdevumus pēc mēneša
    * aprēķināt kopējo summu
    * aprēķināt summas pa kategorijām

Rezultāts:

    * izveidots **logic.py**

---

## 4. posms – Lietotāja interfeiss

Mērķis: izveidot komandrindas izvēlni un lietotāja mijiedarbību.

Uzdevumi:

    * izveidot galveno izvēlni
    * implementēt funkciju izdevuma pievienošanai
    * implementēt izdevumu saraksta parādīšanu
    * implementēt izdevuma dzēšanu

Rezultāts:

    * darbojas **app.py**

---

## 5. posms – CSV eksports

Mērķis: nodrošināt datu eksportēšanu CSV formātā.

Uzdevumi:

    * izveidot funkciju `export_csv()`
    * pārbaudīt CSV faila atvēršanu Excel

Rezultāts:

    * izveidots **export.py**

---

## 6. posms – Testēšana

Mērķis: pārliecināties, ka programma darbojas pareizi.

Testēšanas uzdevumi:

    * pievienot vairākus izdevumus
    * filtrēt pēc dažādiem mēnešiem
    * pārbaudīt kategoriju summas
    * pārbaudīt dzēšanas funkciju
    * eksportēt datus CSV failā

Rezultāts:

* programma darbojas stabilā veidā

---

## Gala rezultāts

Izveidota komandrindas programma, kas ļauj lietotājam:

    * pievienot izdevumus
    * apskatīt izdevumu sarakstu
    * filtrēt izdevumus pēc mēneša
    * redzēt kopsummas pa kategorijām
    * dzēst izdevumus
    * eksportēt datus CSV failā
